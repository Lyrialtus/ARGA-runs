# %%
# Some solutions
# The notation can be improved

# %%
# Some stats for 58 sols from a t400 checkpoint

sols_58 = [[{'abstraction': 'nbccg', 'filters': ['filter_by_degree', 'filter_by_degree'], 'filter_params': [{'degree': 1, 'exclude': True}, {'degree': 4, 'exclude': True}], 'transformation': ['move'], 'transformation_params': [{'direction': 'right', 'limit': 1, 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}, 'limit': 'max', 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'max', 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 4}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color', 'filter_by_size'], 'filter_params': [{'color': 2, 'exclude': False}, {'size': 8, 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_neighbor_color', 'filter_by_neighbor_color'], 'filter_params': [{'color': 1, 'exclude': False}, {'color': 3, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'right', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'up', 'move_mode': 'piercing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'down', 'move_mode': 'piercing'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 4, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}, 'move_mode': 'piercing'}]}],
    [{'abstraction': 'nbhccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 0}]}, {'abstraction': 'nbhccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 3, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 5}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 1, 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_neighbor_color'], 'filter_params': [{'color': 1, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 1, 'exclude': True}]}, 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 'max', 'move_mode': 'blasting'}]}],
    [{'abstraction': 'nbvccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'up', 'limit': 'max', 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 1, 'overlap': True}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['rotate'], 'transformation_params': [{'rotation': 180}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 3, 'image_point': 'bottom', 'relative_position': 'middle'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'up', 'move_mode': 'piercing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 2, 'image_point': 'right', 'relative_position': 'middle'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'piercing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': -1, 'image_point': 'top', 'relative_position': 'source'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 1, 'image_point': 'right', 'relative_position': 'target'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 3, 'image_point': 'bottom', 'relative_position': 'target'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': -1, 'image_point': 'top', 'relative_position': 'source'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 1}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 0}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 8}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 3}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 3, 'exclude': True}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 4, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'bottom', 'relative_position': 'target'}]}],
    [{'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['rotate'], 'transformation_params': [{'rotation': 180}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 1, 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 8}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['flip'], 'transformation_params': [{'mirror_direction': 'horizontal'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['mirror'], 'transformation_params': [{'mirror_axis': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['flip'], 'transformation_params': [{'mirror_direction': 'vertical'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 2}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 8, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': True}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 0, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 2, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 3, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 2, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['flip'], 'transformation_params': [{'mirror_direction': 'diagonal_left'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_size', 'filter_by_size'], 'filter_params': [{'size': 4, 'exclude': True}, {'size': 'odd', 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 2, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'max', 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 5}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['flip'], 'transformation_params': [{'mirror_direction': 'diagonal_left'}]}],
    [{'abstraction': 'nbvccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 1, 'move_mode': 'touching'}]}, {'abstraction': 'nbvccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 1, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 0}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color', 'filter_by_color'], 'filter_params': [{'color': 1, 'exclude': True}, {'color': 2, 'exclude': True}], 'transformation': ['move'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}, 'limit': 'max', 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 1, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 6, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 1, 'exclude': True}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 3}]}],
    [{'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}, {'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 0, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 2}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'down', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}, 'move_mode': 'piercing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 4, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 8, 'overlap': True}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 16, 'exclude': True}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 7, 'overlap': True}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size', 'filter_by_size'], 'filter_params': [{'size': 16, 'exclude': True}, {'size': 12, 'exclude': True}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 6, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 7, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 5}]}],
    [{'abstraction': 'nbhccg', 'filters': ['filter_by_color', 'filter_by_neighbor_color'], 'filter_params': [{'color': 5, 'exclude': False}, {'color': 5, 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 5, 'exclude': True}]}}]}, {'abstraction': 'nbhccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 5, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 5, 'exclude': True}]}}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'down', 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 6, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}],
    [{'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_neighbor_color'], 'filter_params': [{'color': 3, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 2, 'exclude': True}]}, 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 0}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 3, 'overlap': True}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 1}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 5, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 5, 'exclude': True}]}}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_degree'], 'filter_params': [{'degree': 0, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}, 'move_mode': 'touching'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}, 'relative_position': 'middle'}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'max', 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 4}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}],
    [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['rotate'], 'transformation_params': [{'rotation': 270}]}],
    [{'abstraction': 'nbvccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 3, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 0}]}, {'abstraction': 'nbvccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 0, 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}],
    [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['mirror'], 'transformation_params': [{'mirror_axis': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 0, 'exclude': True}]}}]}]]

# %%
import numpy as np

abstractions = [x[0]['abstraction'] for x in sols_58]
names, counts = np.unique(abstractions, return_counts=True)
print(dict(zip(names, counts)))

flat = [x for y in sols_58 for x in y]
transformations = [x['transformation'] for x in flat]
names, counts = np.unique(transformations, return_counts=True)
print(dict(zip(names, counts)))

filters = [x for y in flat for x in y['filters']]
names, counts = np.unique(filters, return_counts=True)
print(dict(zip(names, counts)))
# Out:
# {'mcccg': 3, 'nag': 7, 'nbccg': 43, 'nbhccg': 2, 'nbvccg': 3}
# {'add_border': 4, 'extend': 13, 'fill_rectangle': 10, 'flip': 4, 'hollow_rectangle': 4, 'insert': 13, 'mirror': 2, 'move': 7, 'rotate': 3, 'update_color': 32}
# {'filter_by_color': 29, 'filter_by_degree': 3, 'filter_by_neighbor_color': 5, 'filter_by_nothing': 39, 'filter_by_size': 23}

# %%
# Encountered t100 sols (some were lost)

sol_t4_025d127b = [{'abstraction': 'nbccg', 'filters': ['filter_by_degree'], 'filter_params': [{'degree': 1, 'exclude': True}], 'transformation': ['move'], 'transformation_params': [{'direction': 'right', 'limit': 1, 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_degree'], 'filter_params': [{'degree': 4, 'exclude': False}], 'transformation': ['move'], 'transformation_params': [{'direction': 'left', 'limit': 1, 'move_mode': 'touching'}]}]

sol_t8_05f2a901 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 'same', 'exclude': True}]}, 'limit': 'max', 'move_mode': 'touching'}]}]

sol_t10_08ed6ac7 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 1}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'max', 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 4}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color', 'filter_by_size'], 'filter_params': [{'color': 2, 'exclude': False}, {'size': 8, 'exclude': True}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_neighbor_color', 'filter_by_neighbor_color'], 'filter_params': [{'color': 1, 'exclude': False}, {'color': 3, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}]

sol_t12_0962bcdd = [{'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}, {'abstraction': 'mcccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 5, 'exclude': False}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 0}]}, {'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 4, 'overlap': False}]}]

sol_t24_178fcbfb = [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'right', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'up', 'move_mode': 'piercing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'down', 'move_mode': 'piercing'}]}]

sol_t28_1bfc4729 = [{'abstraction': 'mcccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': True}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 'max', 'move_mode': 'touching'}]}, {'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': {'filters': ['param_bind_node_by_shape'], 'filter_params': [{}]}, 'relative_position': 'middle'}]}, {'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'right', 'limit': 'max', 'move_mode': 'piercing'}]}]

sol_t32_1e0a9b12 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 'max', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 'max', 'move_mode': 'touching'}]}]

sol_t41_22168020 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 'same', 'exclude': False}]}, 'move_mode': 'touching'}]}]

sol_t45_22eb0ac0 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 'same', 'exclude': False}]}, 'move_mode': 'touching'}]}]

sol_t51_25d487eb = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 4, 'exclude': False}]}, 'move_mode': 'phasing'}]}]
sol_t52_25d8a9c8 = [{'abstraction': 'nbhccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['update_color'], 'transformation_params': [{'color': 0}]}, {'abstraction': 'nbhccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'max', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 5}]}]
sol_t53_25ff71a9 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 1, 'move_mode': 'touching'}]}]

sol_t64_2c608aff = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 1, 'exclude': True}]}, 'move_mode': 'touching'}]}]

sol_t73_3618c87e = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'down', 'limit': 'max', 'move_mode': 'piercing'}]}]

sol_t78_3906de3d = [{'abstraction': 'nbvccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'up', 'limit': 'max', 'move_mode': 'touching'}]}]

sol_t81_3aa6fb7a = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 1, 'overlap': True}]}]

sol_t84_3bd67248 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 1, 'image_point': 'bottom_right', 'relative_position': 'target'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'right', 'relative_position': 'middle'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 2, 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'up_right', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'down_left', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 0}]}]

sol_t87_3c9b0459 = [{'abstraction': 'nag', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['flip_rotate'], 'transformation_params': [{'flip_rotation': (None, 180)}]}]

sol_t94_41e4d17e = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 3, 'image_point': 'bottom', 'relative_position': 'middle'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 2, 'image_point': 'right', 'relative_position': 'middle'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'phasing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'up', 'move_mode': 'phasing'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 1, 'image_point': 'right', 'relative_position': 'target'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 3, 'image_point': 'bottom', 'relative_position': 'target'}]}]
sol_t95_4258a5f9 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 1}]}]

sol_t98_4347f46a = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 0}]}]

# %%
# Encountered e400 sols (not many)

sol_e26_12eac192 = [{'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 2, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 3}]}]

sol_e70_292dd178 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['fill_rectangle'], 'transformation_params': [{'fill_color': 2, 'overlap': True}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'right', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': True}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': True}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 1, 'image_point': {'filters': ['param_bind_node_by_color'], 'filter_params': [{'color': 1, 'exclude': True}]}, 'relative_position': 'target'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': False}], 'transformation': ['insert'], 'transformation_params': [{'object_id': 0, 'image_point': 'top', 'relative_position': 'source'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_size'], 'filter_params': [{'size': 'min', 'exclude': True}], 'transformation': ['move'], 'transformation_params': [{'direction': {'filters': ['param_bind_node_by_shape'], 'filter_params': [{}]}, 'limit': 'max', 'move_mode': 'piercing'}]}]

sol_e72_2a5f8217 = [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': {'filters': ['param_bind_node_by_shape'], 'filter_params': [{}]}}]}]

sol_e105_45737921 = [{'abstraction': 'mcccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['swap_colors'], 'transformation_params': [{}]}]

sol_e126_516b51b7 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 2}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 3}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 2}]}]

sol_e242_9c56f360 = [{'abstraction': 'nbhccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 3, 'exclude': False}], 'transformation': ['move'], 'transformation_params': [{'direction': 'left', 'limit': 'max', 'move_mode': 'touching'}]}]

sol_e303_c7d4e6ad = [{'abstraction': 'nbhccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 5, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': {'filters': ['param_bind_neighbor_by_color'], 'filter_params': [{'color': 'same', 'exclude': True}]}}]}, {'abstraction': 'nbhccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 5, 'exclude': False}], 'transformation': ['update_color'], 'transformation_params': [{'color': 2}]}]

sol_e379_f0df5ff0 = [{'abstraction': 'nbccg', 'filters': ['filter_by_color'], 'filter_params': [{'color': 1, 'exclude': False}], 'transformation': ['add_border'], 'transformation_params': [{'border_color': 1}]}]

sol_e395_fc754716 = [{'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['move'], 'transformation_params': [{'direction': 'up', 'limit': 'max', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'left', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'right', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['extend'], 'transformation_params': [{'direction': 'down', 'move_mode': 'touching'}]}, {'abstraction': 'nbccg', 'filters': ['filter_by_nothing'], 'filter_params': [{}], 'transformation': ['hollow_rectangle'], 'transformation_params': [{'fill_color': 0}]}]
